# %% [markdown]
# # Lab 8: Data Visualizations using Python

# %% [markdown]
# 1. Download Python Anaconda & Jupyter notebook extension (on VSCode)
# 2. Create a virtual environment using conda.
#     ```bash
#         conda create --name info5100
#     ```
# 3. Activate the virtual environment
#     ```bash
#         conda activate info5100
#     ```
# 4. Install the following libraries:
#     - pandas
#     ```bash
#         pip install pandas
#     ```
#     - matplotlib
#     ```bash
#         pip install matplotlib
#     ```
#     - seaborn
#     ```bash
#         pip install seaborn
#     ```
# 5. All Set to Run This Jupyter Notebook (.ipynb file)
# 6. Select the Kernal in Top Right Corner (on VSCode)
# 7. In the end to exit from the virtual environment:
#     ```bash
#         conda deactivate
#     ```

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
from IPython.display import Image, display

# Path to your image folder (can be relative or absolute)
image_folder = './Fast_Furious_Insured/testImages'  # or '/Users/soumya/Documents/images'

# %% [markdown]
# If all the libraries are installed, the above cell should run successfully.

# %%
# Loading a dataset:
cars_dataframe = pd.read_csv('Fast_Furious_Insured/test.csv')

# %%
import os
print(os.getcwd())
# Out:
# /Users/soumyasingh/Documents/Northeastern University/INFO5100/soumya-singh/Lab8_Python

# %%
cars_dataframe
# Out:
#           Image_path Insurance_company  Cost_of_vehicle  Min_coverage  \
# 0    img_4538519.jpg                 B            23600         590.0
# 1    img_7766002.jpg                 C            28300         707.5
# 2    img_4637390.jpg                AC            43700        1092.5
# 3    img_4516108.jpg                BB            46100        1152.5
# 4    img_4517008.jpg                BB            40700        1017.5
# ..               ...               ...              ...           ...
# 595  img_7766518.jpg                 B            30900         772.5
# 596  img_4535713.jpg                 O            51300        1282.5
# 597  img_4511787.jpg                BQ            27000         675.0
# 598  img_4517592.jpg                AA            42600        1065.0
# 599  img_4635378.jpg                RE            49300        1232.5
#
#     Expiry_date  Max_coverage
# 0    2025-04-12       5978.00
# 1    2028-08-24       7153.00
# 2    2023-11-28      11003.00
# ...

# %%
cars_dataframe.head(-10)
# Out:
#           Image_path Insurance_company  Cost_of_vehicle  Min_coverage  \
# 0    img_4538519.jpg                 B            23600         590.0
# 1    img_7766002.jpg                 C            28300         707.5
# 2    img_4637390.jpg                AC            43700        1092.5
# 3    img_4516108.jpg                BB            46100        1152.5
# 4    img_4517008.jpg                BB            40700        1017.5
# ..               ...               ...              ...           ...
# 585  img_4517819.jpg                BB            33600         840.0
# 586  img_4536633.jpg                BB            24500         612.5
# 587  img_7767022.jpg                BQ            53100        1327.5
# 588  img_4538822.jpg                BQ            36500         912.5
# 589  img_4538654.jpg                BC            39100         977.5
#
#     Expiry_date  Max_coverage
# 0    2025-04-12        5978.0
# 1    2028-08-24        7153.0
# 2    2023-11-28       11003.0
# ...

# %%
cars_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Image_path         600 non-null    object
#  1   Insurance_company  600 non-null    object
#  2   Cost_of_vehicle    600 non-null    int64
#  3   Min_coverage       600 non-null    float64
#  4   Expiry_date        600 non-null    object
#  5   Max_coverage       600 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 28.3+ KB

# %% [markdown]
# ## Line Plot
#
# ### Univariate
# Visual representation of the relationship of a single column in a dataset.

# %%
plt.plot(cars_dataframe["Min_coverage"], cars_dataframe['Min_coverage'])
plt.title("Min Vs. Max")
plt.xlabel("Min. Coverage")
plt.ylabel("Max. Coverage")
# Save chart as image
plt.savefig('Images-Data-Visualization/linePlot_Cars.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Scatter Plot
#
# ### Bivariate
# Visual representation of the relationship between two variables in a dataset.

# %%
plt.grid(True)
plt.scatter(cars_dataframe["Cost_of_vehicle"], cars_dataframe["Max_coverage"])
plt.title("Cost vs Max coverage")
plt.xlabel("Cost ($)")
plt.ylabel("Max Coverage")
# Save chart as image
plt.savefig('Images-Data-Visualization/scatterPlot_Cars.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Max Coverage')

# %% [markdown]
# ### Multivariate
# Visual representation of the relationship between three or more columns/ variables in a dataset.

# %% [markdown]
# ## Histograms

# %%
sns.histplot(data=cars_dataframe, x="Cost_of_vehicle")
plt.title("Overall Analysis of Vehicles")
plt.xlabel("Cost of Vehicle")
plt.ylabel("Maximum Coverage")

# Save chart as image
plt.savefig('Images-Data-Visualization/histogram_Cars.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Maximum Coverage')

# %%
# Keep only numeric columns
numeric_df = cars_dataframe.select_dtypes(include='number')

# Now compute the correlation
correlation = numeric_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')


# Save chart as image
plt.savefig('Images-Data-Visualization/corelation_heatMap_Cars.png', dpi=300, bbox_inches='tight')

plt.show()
